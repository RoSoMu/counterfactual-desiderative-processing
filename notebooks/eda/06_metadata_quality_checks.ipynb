# %% [markdown]
# # Metadata (second) Check

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Import metadata

# %%
metadata = pd.read_csv("../../data/raw/metadata_raw.csv")
responses = pd.read_csv("../../data/raw/counterfactual_responses_raw.csv")

# %%
metadata.shape
# Out:
# (56, 19)

# %% [markdown]
# Data types

# %%
metadata.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EXP             56 non-null     int64
#  1   n               56 non-null     int64
#  2   Participant_ID  56 non-null     str
#  3   Age             56 non-null     int64
#  4   Gender          56 non-null     int64
#  5   Kno_Level       56 non-null     int64
#  6   Per_Level       56 non-null     int64
#  7   Bilingual       56 non-null     int64
#  8   Bi_Parents      56 non-null     int64
#  9   Multi_Kno       56 non-null     int64
#  10  Multi_Spk       56 non-null     int64
#  11  Immersion       56 non-null     int64
#  12  Prof_Need       56 non-null     int64
#  13  Prof_Use        56 non-null     int64
#  14  Motivation      56 non-null     int64
#  15  Agent           56 non-null     int64
#  16  Distractor      56 non-null     int64
#  17  GN_Score        56 non-null     int64
#  18  Difficulty      56 non-null     int64
# dtypes: int64(18), str(1)
# memory usage: 8.4 KB

# %% [markdown]
# Value counts

# %%
for col in ["EXP", "Gender", "Kno_Level", "Per_Level", "Motivation", "GN_Score", "Difficulty"]:
    print(col)
    print(metadata[col].value_counts(dropna=False).sort_index())
    print()
# Out:
# EXP
# EXP
# 1    32
# 2    24
# Name: count, dtype: int64
#
# Gender
# Gender
# 0    25
# 1    31
# Name: count, dtype: int64
#
# Kno_Level
# Kno_Level
# 1     1
# 4     4
# 5     1
# 6    14
# 7    15
# 8    18
# 9     3
# Name: count, dtype: int64
#
# Per_Level
# Per_Level
# 5     7
# 6    11
# 7    27
# 8    10
# 9     1
# Name: count, dtype: int64
#
# Motivation
# Motivation
# 1     1
# 2     1
# 3     8
# 4    11
# 5    17
# 6    18
# Name: count, dtype: int64
#
# GN_Score
# GN_Score
# 21    3
# 22    3
# 23    2
# 24    6
# 25    2
# 26    6
# 27    5
# 28    4
# 29    4
# 30    4
# 31    1
# 32    3
# 33    4
# 34    2
# 35    2
# 36    4
# 39    1
# Name: count, dtype: int64
#
# Difficulty
# Difficulty
# 1     2
# 2     2
# 3     3
# 4     3
# 5     1
# 6     9
# 7    14
# 8    15
# 9     7
# Name: count, dtype: int64

# %% [markdown]
# Column names

# %%
metadata.columns
# Out:
# Index(['EXP', 'n', 'Participant_ID', 'Age', 'Gender', 'Kno_Level', 'Per_Level',
#        'Bilingual ', 'Bi_Parents', 'Multi_Kno', 'Multi_Spk', 'Immersion',
#        'Prof_Need', 'Prof_Use', 'Motivation', 'Agent', 'Distractor',
#        'GN_Score', 'Difficulty'],
#       dtype='str')

# %% [markdown]
# Unique values for level related categorical values

# %%
metadata["Kno_Level"].unique()
# Out:
# array([6, 4, 7, 8, 9, 1, 5])

# %%
metadata["Per_Level"].unique()
# Out:
# array([7, 5, 9, 8, 6])

# %% [markdown]
# Missing values

# %%
metadata.isnull().sum()
# Out:
# EXP               0
# n                 0
# Participant_ID    0
# Age               0
# Gender            0
# Kno_Level         0
# Per_Level         0
# Bilingual         0
# Bi_Parents        0
# Multi_Kno         0
# Multi_Spk         0
# Immersion         0
# Prof_Need         0
# Prof_Use          0
# Motivation        0
# Agent             0
# Distractor        0
# GN_Score          0
# Difficulty        0
# dtype: int64

# %% [markdown]
# Participant_ID integrity

# %%
metadata["Participant_ID"].nunique()
# Out:
# 56

# %%
responses = responses.rename(
    columns={"Partcipant_ID": "Participant_ID"}
)

responses["Participant_ID"].nunique()
# Out:
# 56
