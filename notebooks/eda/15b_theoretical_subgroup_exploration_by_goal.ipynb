# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Read data and sanity checks

# %%
subgroup_theoretical = pd.read_csv("../../data/processed/subgroup_theoretical.csv")

# %%
subgroup_theoretical[
    [
        "Goal_Type",
        "Item",
        "Consequent_Reversibility",
        "Goal_Oriented_Behaviour",
        "Emotional_Load"
    ]
].drop_duplicates()
# Out:
#            Goal_Type   Item Consequent_Reversibility Goal_Oriented_Behaviour  \
# 0            no_goal  Item1                      Yes                      No
# 1            no_goal  Item2                      Yes                      No
# 2  goal_non_frequent  Item1                       No                      No
# 3  goal_non_frequent  Item2                       No                      No
# 4      goal_frequent  Item1                      Yes                     Yes
# 5      goal_frequent  Item2                      Yes                     Yes
#
#   Emotional_Load
# 0             No
# 1             No
# 2            Yes
# 3            Yes
# 4             No
# 5             No

# %%
subgroup_theoretical.columns
# Out:
# Index(['Participant_ID', 'Focus', 'Agent', 'Goal_Type', 'Item', 'Item_string',
#        'Item_len', 'Response_tag', 'Response', 'Response_Full', 'EXP', 'n',
#        'Age', 'Gender', 'Kno_Level', 'Per_Level', 'Bilingual', 'Bi_Parents',
#        'Multi_Kno', 'Multi_Spk', 'Immersion', 'Prof_Need', 'Prof_Use',
#        'Motivation', 'Distractor', 'GN_Score', 'Difficulty', 'Kno_Level_Label',
#        'Per_Level_Label', 'Prof_Need_Label', 'Prof_Use_Label',
#        'Consequent_Reversibility', 'Goal_Oriented_Behaviour',
#        'Emotional_Load'],
#       dtype='str')

# %%
subgroup_theoretical.shape
# Out:
# (198, 34)

# %% [markdown]
# Overall subgroup proportions

# %% [markdown]
# Response Proportion by Goal Type and Consequent Reversiblity

# %%
goal_reversibility_props= pd.crosstab(
    [subgroup_theoretical["Goal_Type"], subgroup_theoretical["Consequent_Reversibility"]],
    subgroup_theoretical["Response_Full"],
    normalize="index"
)

goal_reversibility_props
# Out:
# Response_Full                               L1_transfer  L2_other   correct
# Goal_Type         Consequent_Reversibility
# goal_frequent     Yes                          0.384615  0.246154  0.369231
# goal_non_frequent No                           0.560606  0.151515  0.287879
# no_goal           Yes                          0.531250  0.187500  0.281250

# %%
goal_reversibility_props.plot(kind = "bar", stacked=True)

plt.title("Response Proportions by Goal Type and Consequent Reversibility")
plt.legend(title="Response", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.xlabel("Consequent Reversibilty")
plt.ylabel("Proportion")
plt.show()

# %% [markdown]
# Response proportion by Goal Type and Goal Oriented Behaviour

# %%
goal_goal_behaviour_props= pd.crosstab(
    [subgroup_theoretical["Goal_Type"],subgroup_theoretical["Goal_Oriented_Behaviour"]],
    subgroup_theoretical["Response_Full"],
    normalize="index"
)

goal_goal_behaviour_props
# Out:
# Response_Full                              L1_transfer  L2_other   correct
# Goal_Type         Goal_Oriented_Behaviour
# goal_frequent     Yes                         0.384615  0.246154  0.369231
# goal_non_frequent No                          0.560606  0.151515  0.287879
# no_goal           No                          0.531250  0.187500  0.281250

# %%
goal_goal_behaviour_props.plot(kind = "bar", stacked=True)

plt.title("Response Proportions by Goal Type and Goal Oriented Behaviour")
plt.legend(title="Response", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.xlabel("Goal Oriented Behaviour")
plt.ylabel("Proportion")
plt.show()

# %% [markdown]
# Response proportion by Goal Type and Emotional Load

# %%
goal_emotional_load_props= pd.crosstab(
    [subgroup_theoretical["Goal_Type"],subgroup_theoretical["Emotional_Load"]],
    subgroup_theoretical["Response_Full"],
    normalize="index"
)

goal_emotional_load_props
# Out:
# Response_Full                     L1_transfer  L2_other   correct
# Goal_Type         Emotional_Load
# goal_frequent     No                 0.384615  0.246154  0.369231
# goal_non_frequent Yes                0.560606  0.151515  0.287879
# no_goal           No                 0.531250  0.187500  0.281250

# %%
goal_emotional_load_props.plot(kind = "bar", stacked=True)

plt.title("Response Proportions by Goal Type and Emotional Load")
plt.legend(title="Response", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.xlabel("Emotional Load")
plt.ylabel("Proportion")
plt.show()

# %% [markdown]
# Actors vs Readers

# %% [markdown]
# Actors subgroup proportions

# %%
subgroup_theoretical_actors = subgroup_theoretical[subgroup_theoretical["Focus"] == "I"].copy()

# %%
subgroup_theoretical_actors.shape
# Out:
# (120, 34)

# %% [markdown]
# Response Proportion by Goal Type and Consequent_Reversiblity

# %%
goal_reversibility_props_a= pd.crosstab(
    [subgroup_theoretical_actors["Goal_Type"],subgroup_theoretical_actors["Consequent_Reversibility"]],
    subgroup_theoretical_actors["Response_Full"],
    normalize="index"
)

goal_reversibility_props_a
# Out:
# Response_Full                               L1_transfer  L2_other   correct
# Goal_Type         Consequent_Reversibility
# goal_frequent     Yes                          0.333333  0.256410  0.410256
# goal_non_frequent No                           0.450000  0.225000  0.325000
# no_goal           Yes                          0.578947  0.131579  0.289474

# %%
goal_reversibility_props_a.plot(kind = "bar", stacked=True)

plt.title("Response Proportions by Goal Type Consequent Reversibility for Actors")
plt.legend(title="Response", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.xlabel("Consequent Reversibilty")
plt.ylabel("Proportion")
plt.show()

# %% [markdown]
# Response Proportion by Goal_Oriented_Behavour

# %%
goal_goal_behaviour_props_a= pd.crosstab(
    [subgroup_theoretical_actors["Goal_Type"],subgroup_theoretical_actors["Goal_Oriented_Behaviour"]],
    subgroup_theoretical_actors["Response_Full"],
    normalize="index"
)

goal_goal_behaviour_props_a
# Out:
# Response_Full                              L1_transfer  L2_other   correct
# Goal_Type         Goal_Oriented_Behaviour
# goal_frequent     Yes                         0.333333  0.256410  0.410256
# goal_non_frequent No                          0.450000  0.225000  0.325000
# no_goal           No                          0.578947  0.131579  0.289474

# %%
goal_goal_behaviour_props_a.plot(kind = "bar", stacked=True)

plt.title("Response Proportions by Goal Type and Goal Oriented Behaviour for Actors")
plt.legend(title="Response", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.xlabel("Goal Oriented Behaviour")
plt.ylabel("Proportion")
plt.show()

# %% [markdown]
# Overall subgroup proportions

# %% [markdown]
# Response Proportion by Goal Type and Emotional Load

# %%
goal_emotional_load_props_a= pd.crosstab(
    [subgroup_theoretical_actors["Goal_Type"],subgroup_theoretical_actors["Emotional_Load"]],
    subgroup_theoretical_actors["Response_Full"],
    normalize="index"
)

goal_emotional_load_props_a
# Out:
# Response_Full                     L1_transfer  L2_other   correct
# Goal_Type         Emotional_Load
# goal_frequent     No                 0.333333  0.256410  0.410256
# goal_non_frequent Yes                0.450000  0.225000  0.325000
# no_goal           No                 0.578947  0.131579  0.289474

# %%
goal_emotional_load_props_a.plot(kind = "bar", stacked=True)

plt.title("Response Proportions by Goal Type and Emotional Load for Actors")
plt.legend(title="Response", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.xlabel("Emotional Load")
plt.ylabel("Proportion")
plt.show()

# %% [markdown]
# Readers subgroup proportions

# %%
subgroup_theoretical_readers = subgroup_theoretical[subgroup_theoretical["Focus"] == "They"].copy()

# %%
subgroup_theoretical_readers.shape
# Out:
# (78, 34)

# %% [markdown]
# Response Proportion by Goal Type and Consequent Reversiblity

# %%
goal_reversibility_props_r= pd.crosstab(
    [subgroup_theoretical_readers["Goal_Type"],subgroup_theoretical_readers["Consequent_Reversibility"]],
    subgroup_theoretical_readers["Response_Full"],
    normalize="index"
)

goal_reversibility_props_r
# Out:
# Response_Full                               L1_transfer  L2_other   correct
# Goal_Type         Consequent_Reversibility
# goal_frequent     Yes                          0.461538  0.230769  0.307692
# goal_non_frequent No                           0.730769  0.038462  0.230769
# no_goal           Yes                          0.461538  0.269231  0.269231

# %%
goal_reversibility_props_r.plot(kind = "bar", stacked=True)

plt.title("Response Proportions by Goal Type and Consequent Reversibility for Readers")
plt.legend(title="Response", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.xlabel("Consequent Reversibilty")
plt.ylabel("Proportion")
plt.show()

# %% [markdown]
# Response Proportion by Goal Type and Goal Oriented Behaviour

# %%
goal_goal_behaviour_props_r= pd.crosstab(
    [subgroup_theoretical_readers["Goal_Type"],subgroup_theoretical_readers["Goal_Oriented_Behaviour"]],
    subgroup_theoretical_readers["Response_Full"],
    normalize="index"
)

goal_goal_behaviour_props_r
# Out:
# Response_Full                              L1_transfer  L2_other   correct
# Goal_Type         Goal_Oriented_Behaviour
# goal_frequent     Yes                         0.461538  0.230769  0.307692
# goal_non_frequent No                          0.730769  0.038462  0.230769
# no_goal           No                          0.461538  0.269231  0.269231

# %%
goal_goal_behaviour_props_r.plot(kind = "bar", stacked=True)

plt.title("Response Proportions by Goal Type and Goal Oriented Behaviour for Readers")
plt.legend(title="Response", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.xlabel("Goal Oriented Behaviour")
plt.ylabel("Proportion")
plt.show()

# %% [markdown]
# Response Proportion by Goal Type and Emotional Load

# %%
goal_emotional_load_props_r= pd.crosstab(
    [subgroup_theoretical_readers["Goal_Type"],subgroup_theoretical_readers["Emotional_Load"]],
    subgroup_theoretical_readers["Response_Full"],
    normalize="index"
)

goal_emotional_load_props_r
# Out:
# Response_Full                     L1_transfer  L2_other   correct
# Goal_Type         Emotional_Load
# goal_frequent     No                 0.461538  0.230769  0.307692
# goal_non_frequent Yes                0.730769  0.038462  0.230769
# no_goal           No                 0.461538  0.269231  0.269231

# %%
goal_emotional_load_props_r.plot(kind = "bar", stacked=True)

plt.title("Response Proportions by Goal Type and Emotional Load for Readers")
plt.legend(title="Response", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.xlabel("Emotional Load")
plt.ylabel("Proportion")
plt.show()
