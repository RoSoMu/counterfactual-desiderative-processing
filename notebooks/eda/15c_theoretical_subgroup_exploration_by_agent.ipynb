# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Read data and sanity checks

# %%
subgroup_theoretical = pd.read_csv("../../data/processed/subgroup_theoretical.csv")

# %%
subgroup_theoretical[
    [
        "Goal_Type",
        "Item",
        "Consequent_Reversibility"
    ]
].drop_duplicates()
# Out:
#            Goal_Type   Item Consequent_Reversibility
# 0            no_goal  Item1                      Yes
# 1            no_goal  Item2                      Yes
# 2  goal_non_frequent  Item1                       No
# 3  goal_non_frequent  Item2                       No
# 4      goal_frequent  Item1                      Yes
# 5      goal_frequent  Item2                      Yes

# %%
subgroup_theoretical.columns
# Out:
# Index(['Participant_ID', 'Focus', 'Agent', 'Goal_Type', 'Item', 'Item_string',
#        'Item_len', 'Response_tag', 'Response', 'Response_Full', 'EXP', 'n',
#        'Age', 'Gender', 'Kno_Level', 'Per_Level', 'Bilingual', 'Bi_Parents',
#        'Multi_Kno', 'Multi_Spk', 'Immersion', 'Prof_Need', 'Prof_Use',
#        'Motivation', 'Distractor', 'GN_Score', 'Difficulty', 'Kno_Level_Label',
#        'Per_Level_Label', 'Prof_Need_Label', 'Prof_Use_Label',
#        'Consequent_Reversibility'],
#       dtype='str')

# %%
subgroup_theoretical.shape
# Out:
# (198, 32)

# %% [markdown]
# Overall subgroup proportions

# %% [markdown]
# Response Proportion by Agent and Consequent Reversiblity

# %%
agent_reversibility_props= pd.crosstab(
    [subgroup_theoretical["Agent"], subgroup_theoretical["Consequent_Reversibility"]],
    subgroup_theoretical["Response_Full"],
    normalize="index"
)

agent_reversibility_props
# Out:
# Response_Full                   L1_transfer  L2_other   correct
# Agent Consequent_Reversibility
# 0     No                           0.500000  0.214286  0.285714
#       Yes                          0.444444  0.271605  0.283951
# 1     No                           0.666667  0.041667  0.291667
#       Yes                          0.479167  0.125000  0.395833

# %%
agent_reversibility_props.plot(kind = "bar", stacked=True)

plt.title("Response Proportions by Agent and Consequent Reversibility")
plt.legend(title="Response", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.xlabel("Consequent Reversibilty")
plt.ylabel("Proportion")
plt.show()

# %% [markdown]
# Response Counts by Agent and Consequent Reversiblity

# %%
agent_reversibility_counts= pd.crosstab(
    [subgroup_theoretical["Agent"], subgroup_theoretical["Consequent_Reversibility"]],
    subgroup_theoretical["Response_Full"]
)

agent_reversibility_counts
# Out:
# Response_Full                   L1_transfer  L2_other  correct
# Agent Consequent_Reversibility
# 0     No                                 21         9       12
#       Yes                                36        22       23
# 1     No                                 16         1        7
#       Yes                                23         6       19

# %% [markdown]
# Actors vs Readers

# %% [markdown]
# Actors subgroup proportions

# %%
subgroup_theoretical_actors = subgroup_theoretical[subgroup_theoretical["Focus"] == "I"].copy()

# %%
subgroup_theoretical_actors.shape
# Out:
# (120, 32)

# %% [markdown]
# Response Proportion by Agent and Consequent Reversiblity for Actors

# %%
agent_reversibility_props_a= pd.crosstab(
    [subgroup_theoretical_actors["Agent"],subgroup_theoretical_actors["Consequent_Reversibility"]],
    subgroup_theoretical_actors["Response_Full"],
    normalize="index"
)

agent_reversibility_props_a
# Out:
# Response_Full                   L1_transfer  L2_other   correct
# Agent Consequent_Reversibility
# 0     No                           0.291667  0.333333  0.375000
#       Yes                          0.422222  0.244444  0.333333
# 1     No                           0.687500  0.062500  0.250000
#       Yes                          0.500000  0.125000  0.375000

# %%
agent_reversibility_props_a.plot(kind = "bar", stacked=True)

plt.title("Response Proportions by Agent Consequent Reversibility for Actors")
plt.legend(title="Response", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.xlabel("Consequent Reversibilty")
plt.ylabel("Proportion")
plt.show()

# %% [markdown]
# Response Counts by Agent and Consequent Reversiblity for Actors

# %%
agent_reversibility_counts_a= pd.crosstab(
    [subgroup_theoretical_actors["Agent"],subgroup_theoretical_actors["Consequent_Reversibility"]],
    subgroup_theoretical_actors["Response_Full"]
)

agent_reversibility_counts_a
# Out:
# Response_Full                   L1_transfer  L2_other  correct
# Agent Consequent_Reversibility
# 0     No                                  7         8        9
#       Yes                                19        11       15
# 1     No                                 11         1        4
#       Yes                                16         4       12

# %% [markdown]
# Readers subgroup proportions

# %%
subgroup_theoretical_readers = subgroup_theoretical[subgroup_theoretical["Focus"] == "They"].copy()

# %%
subgroup_theoretical_readers.shape
# Out:
# (78, 32)

# %% [markdown]
# Response Proportion by Agent and Consequent Reversiblity for Readers

# %%
agent_reversibility_props_r= pd.crosstab(
    [subgroup_theoretical_readers["Agent"],subgroup_theoretical_readers["Consequent_Reversibility"]],
    subgroup_theoretical_readers["Response_Full"],
    normalize="index"
)

agent_reversibility_props_r
# Out:
# Response_Full                   L1_transfer  L2_other   correct
# Agent Consequent_Reversibility
# 0     No                           0.777778  0.055556  0.166667
#       Yes                          0.472222  0.305556  0.222222
# 1     No                           0.625000  0.000000  0.375000
#       Yes                          0.437500  0.125000  0.437500

# %%
agent_reversibility_props_r.plot(kind = "bar", stacked=True)

plt.title("Response Proportions by Agent and Consequent Reversibility for Readers")
plt.legend(title="Response", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.xlabel("Consequent Reversibilty")
plt.ylabel("Proportion")
plt.show()

# %% [markdown]
# Response Counts by Agent and Consequent Reversiblity for Readers

# %%
agent_reversibility_counts_r= pd.crosstab(
    [subgroup_theoretical_readers["Agent"],subgroup_theoretical_readers["Consequent_Reversibility"]],
    subgroup_theoretical_readers["Response_Full"]
)

agent_reversibility_counts_r
# Out:
# Response_Full                   L1_transfer  L2_other  correct
# Agent Consequent_Reversibility
# 0     No                                 14         1        3
#       Yes                                17        11        8
# 1     No                                  5         0        3
#       Yes                                 7         2        7
