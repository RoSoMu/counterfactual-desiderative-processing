# %% [markdown]
# # Combined Subgroup: Correct Resolution Model

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Combined Subgroup
#
# 1. Create resolved_correct
# 2. Counts and Proportions
# 3. Logistic Models
#
#     Main Effect Models:
#
#     - RC01: Focus
#     - RC02: Agent
#     - RC03: Goal_Type
#
#     Additive Models:
#
#     - RC04: Focus + Agent
#     - RC05: Focus + Goal_Type
#     - RC06: Agent + Goal_Type
#
#     Interactive Models:
#
#     - RC07: Focus * Agent
#     - RC08: Focus * Goal_Type
#     - RC09: Agent * Goal_Type
#     - RC10: Focus * Agent + Goal_Type
# 4. Model Comparisons
# 5. Summary Table

# %% [markdown]
# Read Data

# %%
subgroup_theoretical = pd.read_csv("../../data/processed/subgroup_theoretical.csv")

# %% [markdown]
# 1. Create resolved_correct
#
# Binary Outcome: include correct responses from escape_L2 observations.

# %%
subgroup_theoretical["escape_L2"] = (
    subgroup_theoretical["Response_Full"] != "L2_other"
).astype(int)

# %%
escapees = subgroup_theoretical[subgroup_theoretical["escape_L2"] == 1].copy()

# %%
escapees["resolved_correct"] = (escapees["Response_Full"] == "correct").astype(int)

# %% [markdown]
# 2. Counts and Proportions

# %%
resolved_correct_counts = pd.crosstab(
    escapees["resolved_correct"],
    escapees["Response_Full"])

resolved_correct_counts
# Out:
# Response_Full     L1_transfer  correct  missing_response
# resolved_correct
# 0                          96        0                 3
# 1                           0       61                 0

# %%
resolved_correct_props = escapees["resolved_correct"].value_counts(normalize = True)
resolved_correct_props
# Out:
# resolved_correct
# 0    0.61875
# 1    0.38125
# Name: proportion, dtype: float64

# %% [markdown]
# From 160 observations, almost 38% of responses that had escaped *L2_other* options were resolved correctly.

# %% [markdown]
# Counts and Proportions by Condition:

# %%
counts_condition = pd.crosstab(
    [escapees["Goal_Type"], escapees["Agent"], escapees["Focus"]],
    escapees["resolved_correct"],
    margins = True)

counts_condition
# Out:
# resolved_correct                0   1  All
# Goal_Type         Agent Focus
# goal_frequent     0     I       7   9   16
#                         They    7   5   12
#                   1     I       7   7   14
#                         They    5   3    8
# goal_non_frequent 0     I       7   9   16
#                         They   14   3   17
#                   1     I      11   4   15
#                         They    5   3    8
# no_goal           0     I      15   6   21
#                         They   10   3   13
#                   1     I       9   5   14
#                         They    2   4    6
# All                            99  61  160

# %%
props_condition = pd.crosstab(
    [escapees["Goal_Type"], escapees["Agent"], escapees["Focus"]],
    escapees["resolved_correct"],
    normalize= "index")

props_condition
# Out:
# resolved_correct                      0         1
# Goal_Type         Agent Focus
# goal_frequent     0     I      0.437500  0.562500
#                         They   0.583333  0.416667
#                   1     I      0.500000  0.500000
#                         They   0.625000  0.375000
# goal_non_frequent 0     I      0.437500  0.562500
#                         They   0.823529  0.176471
#                   1     I      0.733333  0.266667
#                         They   0.625000  0.375000
# no_goal           0     I      0.714286  0.285714
#                         They   0.769231  0.230769
#                   1     I      0.642857  0.357143
#                         They   0.333333  0.666667

# %% [markdown]
# COMMENT GENERAL PROPORTIONS

# %% [markdown]
# 3. Logistic Models

# %% [markdown]
# Import Libraries

# %%
import statsmodels.formula.api as smf
from scipy.stats import chi2

# %%
escapees["resolved_correct"].value_counts()
# Out:
# resolved_correct
# 0    99
# 1    61
# Name: count, dtype: int64

# %% [markdown]
# **Main Effect Models**

# %% [markdown]
# **RC01**
#
# resolved_correct ~ Focus

# %%
RC01 = smf.logit(
    "resolved_correct ~ Focus",
    data=escapees
    ).fit()

print(RC01.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.660653
#          Iterations 4
#                            Logit Regression Results
# ...
# Dep. Variable:       resolved_correct   No. Observations:                  160
# Model:                          Logit   Df Residuals:                      158
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 19 Jul 2026   Pseudo R-squ.:                0.006048
# Time:                        12:18:09   Log-Likelihood:                -105.70
# converged:                       True   LL-Null:                       -106.35
# Covariance Type:            nonrobust   LLR p-value:                    0.2567
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        -0.3365      0.207     -1.625      0.104      -0.742       0.069
# ...

# %% [markdown]
# **RC02**
#
# resolved_correct ~ Agent

# %%
RC02 = smf.logit(
    "resolved_correct ~ Agent",
    data=escapees
    ).fit()

print(RC02.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.664164
#          Iterations 4
#                            Logit Regression Results
# ...
# Dep. Variable:       resolved_correct   No. Observations:                  160
# Model:                          Logit   Df Residuals:                      158
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 19 Jul 2026   Pseudo R-squ.:               0.0007657
# Time:                        12:18:09   Log-Likelihood:                -106.27
# converged:                       True   LL-Null:                       -106.35
# Covariance Type:            nonrobust   LLR p-value:                    0.6865
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5390      0.213     -2.534      0.011      -0.956      -0.122
# ...

# %% [markdown]
# **RC03**
#
# resolved_correct ~ Goal_Type

# %%
RC03 = smf.logit(
    "resolved_correct ~ Goal_Type",
    data= escapees
    ).fit()

print(RC03.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.655378
#          Iterations 4
#                            Logit Regression Results
# ...
# Dep. Variable:       resolved_correct   No. Observations:                  160
# Model:                          Logit   Df Residuals:                      157
# Method:                           MLE   Df Model:                            2
# Date:                Sun, 19 Jul 2026   Pseudo R-squ.:                 0.01398
# Time:                        12:18:09   Log-Likelihood:                -104.86
# converged:                       True   LL-Null:                       -106.35
# Covariance Type:            nonrobust   LLR p-value:                    0.2260
# ...
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# **RC04**
#
# resolved_correct ~ Focus + Agent

# %%
RC04 = smf.logit(
    "resolved_correct ~ Focus + Agent",
    data=escapees
    ).fit()

print(RC04.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.660393
#          Iterations 4
#                            Logit Regression Results
# ...
# Dep. Variable:       resolved_correct   No. Observations:                  160
# Model:                          Logit   Df Residuals:                      157
# Method:                           MLE   Df Model:                            2
# Date:                Sun, 19 Jul 2026   Pseudo R-squ.:                0.006440
# Time:                        12:18:09   Log-Likelihood:                -105.66
# converged:                       True   LL-Null:                       -106.35
# Covariance Type:            nonrobust   LLR p-value:                    0.5042
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        -0.3798      0.256     -1.483      0.138      -0.882       0.122
# ...

# %% [markdown]
# **RC05**
#
# resolved_correct ~ Focus + Goal_Type

# %%
RC05 = smf.logit(
    "resolved_correct ~ Focus + Goal_Type",
    data=escapees
    ).fit()

print(RC05.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.651218
#          Iterations 5
#                            Logit Regression Results
# ...
# Dep. Variable:       resolved_correct   No. Observations:                  160
# Model:                          Logit   Df Residuals:                      156
# Method:                           MLE   Df Model:                            3
# Date:                Sun, 19 Jul 2026   Pseudo R-squ.:                 0.02024
# Time:                        12:18:09   Log-Likelihood:                -104.19
# converged:                       True   LL-Null:                       -106.35
# Covariance Type:            nonrobust   LLR p-value:                    0.2303
# ...
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# **RC06**
#
# resolved_correct ~ Agent + Goal_Type

# %%
RC06 = smf.logit(
    "resolved_correct ~ Agent + Goal_Type",
    data= escapees
    ).fit()

print(RC06.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.655049
#          Iterations 4
#                            Logit Regression Results
# ...
# Dep. Variable:       resolved_correct   No. Observations:                  160
# Model:                          Logit   Df Residuals:                      156
# Method:                           MLE   Df Model:                            3
# Date:                Sun, 19 Jul 2026   Pseudo R-squ.:                 0.01448
# Time:                        12:18:09   Log-Likelihood:                -104.81
# converged:                       True   LL-Null:                       -106.35
# Covariance Type:            nonrobust   LLR p-value:                    0.3795
# ...
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# **RC07**
#
# resolved_correct ~ Focus * Agent

# %%
RC07 = smf.logit(
    "resolved_correct ~ Focus * Agent",
    data= escapees
    ).fit()

print(RC07.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.651207
#          Iterations 5
#                            Logit Regression Results
# ...
# Dep. Variable:       resolved_correct   No. Observations:                  160
# Model:                          Logit   Df Residuals:                      156
# Method:                           MLE   Df Model:                            3
# Date:                Sun, 19 Jul 2026   Pseudo R-squ.:                 0.02026
# Time:                        12:18:09   Log-Likelihood:                -104.19
# converged:                       True   LL-Null:                       -106.35
# Covariance Type:            nonrobust   LLR p-value:                    0.2300
# ...
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              -0.1892      0.276     -0.686      0.493      -0.730       0.352
# ...

# %% [markdown]
# **RC08**
#
# resolved_correct ~ Focus * Goal_Type

# %%
RC08 = smf.logit(
    "resolved_correct ~ Focus * Goal_Type",
    data= escapees
    ).fit()

print(RC08.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.645866
#          Iterations 5
#                            Logit Regression Results
# ...
# Dep. Variable:       resolved_correct   No. Observations:                  160
# Model:                          Logit   Df Residuals:                      154
# Method:                           MLE   Df Model:                            5
# Date:                Sun, 19 Jul 2026   Pseudo R-squ.:                 0.02829
# Time:                        12:18:09   Log-Likelihood:                -103.34
# converged:                       True   LL-Null:                       -106.35
# Covariance Type:            nonrobust   LLR p-value:                    0.3045
# ...
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# **RC09**
#
# resolved_correct ~ Agent * Goal_Type

# %%
RC09 = smf.logit(
    "resolved_correct ~ Agent * Goal_Type",
    data=escapees
    ).fit()

print(RC09.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.648393
#          Iterations 5
#                            Logit Regression Results
# ...
# Dep. Variable:       resolved_correct   No. Observations:                  160
# Model:                          Logit   Df Residuals:                      154
# Method:                           MLE   Df Model:                            5
# Date:                Sun, 19 Jul 2026   Pseudo R-squ.:                 0.02449
# Time:                        12:18:09   Log-Likelihood:                -103.74
# converged:                       True   LL-Null:                       -106.35
# Covariance Type:            nonrobust   LLR p-value:                    0.3909
# ...
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# **RC10**
#
# resolved_correct ~ Focus * Agent + Goal_Type

# %%
RC10 = smf.logit(
    "resolved_correct ~ Focus * Agent + Goal_Type",
    data=escapees
    ).fit()

print(RC10.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.642181
#          Iterations 5
#                            Logit Regression Results
# ...
# Dep. Variable:       resolved_correct   No. Observations:                  160
# Model:                          Logit   Df Residuals:                      154
# Method:                           MLE   Df Model:                            5
# Date:                Sun, 19 Jul 2026   Pseudo R-squ.:                 0.03384
# Time:                        12:18:09   Log-Likelihood:                -102.75
# converged:                       True   LL-Null:                       -106.35
# Covariance Type:            nonrobust   LLR p-value:                    0.2064
# ...
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# 4. Model Comparisons

# %%
from scipy.stats import chi2

def lr_test(model_small, model_large):

    LR = 2 * (model_large.llf - model_small.llf)

    df = model_large.df_model - model_small.df_model

    p = chi2.sf(LR, df)

    return pd.Series({
        "LR": LR,
        "df": df,
        "p_value": p
    })

# %%
lr_test(RC1, RC3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 lr_test(RC1, RC3)
#
# NameError: name 'RC1' is not defined

# %%
lr_test(RC1, RC4)
# Out:
# LR         5.046581
# df         4.000000
# p_value    0.282551
# dtype: float64

# %% [markdown]
# 5. Summary Table

# %%
goal_behaviour = ["Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined", "Combined"]

model_name = ["RC01", "RC02", "RC03", "RC03", "RC04", "RC04", "RC05", "RC05", "RC05", "RC06", "RC06", "RC06", "RC07", "RC07", "RC07", "RC08", "RC08", "RC08", "RC08", "RC08", "RC09", "RC09", "RC09", "RC09", "RC09", "RC10", "RC10", "RC10", "RC10", "RC10"]

outcome = ["resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct", "resolved_correct"]

formula = ["resolved_correct ~ Focus", "resolved_correct ~ Agent", "resolved_correct ~ Goal_Type", "resolved_correct ~ Goal_Type", "resolved_correct ~ Focus + Agent", "resolved_correct ~ Focus + Agent", "resolved_correct ~ Focus + Goal_Type","resolved_correct ~ Focus + Goal_Type", "resolved_correct ~ Focus + Goal_Type", "resolved_correct ~ Agent + Goal_Type", "resolved_correct ~ Agent + Goal_Type", "resolved_correct ~ Agent + Goal_Type", "resolved_correct ~ Focus * Agent", "resolved_correct ~ Focus * Agent", "resolved_correct ~ Focus * Agent", "resolved_correct ~ Focus * Goal_Type", "resolved_correct ~ Focus * Goal_Type", "resolved_correct ~ Focus * Goal_Type", "resolved_correct ~ Focus * Goal_Type", "resolved_correct ~ Focus * Goal_Type", "resolved_correct ~ Agent * Goal_Type", "resolved_correct ~ Agent * Goal_Type", "resolved_correct ~ Agent * Goal_Type", "resolved_correct ~ Agent * Goal_Type", "resolved_correct ~ Agent * Goal_Type", "resolved_correct ~ Focus * Agent + Goal_Type", "resolved_correct ~ Focus * Agent + Goal_Type", "resolved_correct ~ Focus * Agent + Goal_Type", "resolved_correct ~ Focus * Agent + Goal_Type", "resolved_correct ~ Focus * Agent + Goal_Type"]

predictor= ["They", "Agent", "goal_non_frequent", "no_goal", "They", "Agent", "They", "goal_non_frequent", "no_goal", "goal_non_frequent", "no_goal", "Agent", "They", "Agent", "They:Agent", "They", "goal_non_frequent", "no_goal", "They:goal_non_frequent", "They:no_goal", "goal_non_frequent", "no_goal", "Agent", "Agent:goal_non_frequent", "Agent:no_goal", "They", "goal_non_frequent", "no_goal", "Agent", "They:Agent"]

coef = ["RC01", 0.1335, -0.5864, -0.6131, "RC04", "RC04", "RC05", "RC05", "RC05", -0.5837, -0.6059, 0.1086, "RC07", "RC07", "RC07", "RC08", "RC08", "RC08", "RC08", "RC08", -0.5596, -1.0217, -0.1823, -0.0847, 1.0033, "RC10", "RC10", "RC10", "RC10", "RC10"]

std_error = ["RC01", 0.331, 0.400, 0.404, "RC04", "RC04", "RC05", "RC05", "RC05", 0.400, 0.405, 0.334, "RC07", "RC07", "RC07", "RC08", "RC08", "RC08", "RC08", "RC08", 0.523, 0.542, 0.571, 0.814, 0.824, "RC10", "RC10", "RC10", "RC10", "RC10"]

coef_p = ["RC01", 0.686, 0.142, 0.129, "RC04", "RC04", "RC05", "RC05", "RC05", 0.144, 0.135, 0.745, "RC07", "RC07", "RC07", "RC08", "RC08", "RC08", "RC08", "RC08", 0.285, 0.060, 0.750, 0.917, 0.223, "RC10", "RC10", "RC10", "RC10", "RC10"]

LLR_p = ["RC01", 0.6865, 0.2260, 0.2260, "RC04", "RC04", "RC05", "RC05", "RC05", 0.3795, 0.3795, 0.3795, "RC07", "RC07", "RC07", "RC08", "RC08", "RC08", "RC08", "RC08", 0.3909, 0.3909, 0.3909, 0.3909, 0.3909, "RC10", "RC10", "RC10", "RC10", "RC10"]

observations= [160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160]

# %% [markdown]
# correct_summary = pd.DataFrame({
#     "Goal_Behaviour": goal_behaviour,
#     "Model": model_name,
#     "Outcome": outcome,
#     "Formula": formula,
#     "Predictor": predictor,
#     "Coef": coef,
#     "Std_err": std_error,
#     "Coef_p": coef_p,
#     "Model_LLR_p": LLR_p,
#     "N": observations
# })
#
# correct_summary
